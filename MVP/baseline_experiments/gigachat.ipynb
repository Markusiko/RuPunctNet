# %%
from langchain.schema import HumanMessage, SystemMessage
from langchain.chat_models.gigachat import GigaChat
import os
import pandas as pd
import tqdm
import re
import ast
import numpy as np
import time
import joblib
from collections import Counter
from sklearn.metrics import confusion_matrix, roc_auc_score, top_k_accuracy_score,\
                            f1_score, precision_score, recall_score, average_precision_score

# %%
GIGACHAT_TOKEN = os.environ.get('GIGACHAT_TOKEN')

# %%
df_test = pd.read_csv('final_markup/test.csv').sample(n=5000, random_state=999)

# %%
df_test.head()
# Out:
#                                                     text  \
# 10502  Теперь известные как Алая Ведьма и Ртуть, Ванд...
# 66487  Клуб официально зарегистрирован Управлением ку...
# 54312  Через село проходит автодорога Терло — Самбор....
# 4481   В 1958 году была восстановлена пятиярусная тэн...
# 21     Висоза-ду-Сеара (порт. Viçosa do Ceará) — муни...
#
#                                                   tokens  \
# 10502  ['теперь', 'известные', 'как', 'алая', 'ведьма...
# 66487  ['клуб', 'официально', 'зарегистрирован', 'упр...
# 54312  ['через', 'село', 'проходит', 'автодорога', 'т...
# 4481   ['в', '1958', 'году', 'была', 'восстановлена',...
# 21     ['висозадусеара', 'порт', 'viçosa', 'do', 'cea...
#
#                                                   labels
# 10502  ['o', 'o', 'o', 'o', 'o', 'o', ',', 'o', 'o', ...
# 66487  ['o', 'o', 'o', 'o', 'o', 'o', 'o', '.', 'o', ...
# 54312      ['o', 'o', 'o', 'o', 'o', '.', 'o', 'o', '.']
# 4481   ['o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', ...
# 21     ['o', '.', 'o', 'o', 'o', 'o', 'o', ',', 'o', ...

# %%
def gigachat_pred(text):
    chat = GigaChat(model='GigaChat:latest',
                    credentials=GIGACHAT_TOKEN,
                    verify_ssl_certs=False)

    messages = [SystemMessage(content="Расставь в тексте знаки препинания."),
                HumanMessage(content='Текст: \n' + text)]
    answer = chat.invoke(messages).content
    with open('gigachat_preds_test.txt', 'a') as file:
        file.write(answer + '\n')
        file.close()
    return answer

# %%
punctuation_signs = ['!', ',', '.', '...', ':', ';', '?']

def prepare_pred(text):
    text = re.sub('– ', '', text)
    text = re.sub('— ', '', text)
    text = re.sub('"', '', text)
    text = text.lower()
    text = re.sub('\s+', ' ', text)
    
    for sign in punctuation_signs:
        text = text.replace(sign + ' ', ' ')
        
    if text[-1] in punctuation_signs:
        text = text[:-1]
        
    prediction = gigachat_pred(text)
    tokens = [token for token in prediction.split(' ') if token != '']
    labels = []
    
    for token in tokens:
        if (len(token) > 3) & (token[-3:] == '...'):
            labels.append('...')
        elif token[-1] in punctuation_signs:
            labels.append(token[-1])
        else:
            labels.append('o')
    
    return labels

# %%
preds = []
true_labels = []

# процесс падал, поэтому продолжал генерировать с момента падения
for id_text in tqdm.tqdm(range(721+547, len(df_test.text.values))):
    time.sleep(3)
    prediction = prepare_pred(df_test.text.values[id_text])   
    needed_labels = ast.literal_eval(df_test.labels.values[id_text])
    
    # если модель выдала что-то не то по размеру
    if len(prediction) != len(needed_labels):        
        not_empty_token_idxs = ~(np.array(ast.literal_eval(df_test.tokens.values[id_text])) == '')
        needed_labels = np.array(needed_labels)[not_empty_token_idxs].tolist()
        
    if len(needed_labels) == len(prediction):
        true_labels += needed_labels
        preds += prediction
# Out:
#   1%|▌                                      | 50/3732 [03:50<4:31:04,  4.42s/it]Giga generation stopped with reason: blacklist
#   1%|▌                                      | 54/3732 [04:07<4:22:53,  4.29s/it]Giga generation stopped with reason: blacklist
#   2%|▋                                      | 71/3732 [05:25<4:29:03,  4.41s/it]Giga generation stopped with reason: blacklist
#   2%|▉                                      | 92/3732 [06:58<4:17:38,  4.25s/it]Giga generation stopped with reason: blacklist
#   3%|█                                     | 105/3732 [07:56<4:51:30,  4.82s/it]Giga generation stopped with reason: blacklist
#   3%|█▏                                    | 121/3732 [09:09<4:19:52,  4.32s/it]Giga generation stopped with reason: blacklist
#   4%|█▌                                    | 156/3732 [11:57<4:43:13,  4.75s/it]Giga generation stopped with reason: blacklist
#   5%|█▊                                    | 183/3732 [14:11<4:39:19,  4.72s/it]Giga generation stopped with reason: blacklist
#   6%|██▎                                   | 225/3732 [17:30<4:23:21,  4.51s/it]Giga generation stopped with reason: blacklist
#   6%|██▎                                   | 231/3732 [17:56<4:16:59,  4.40s/it]Giga generation stopped with reason: blacklist
#   7%|██▋                                   | 261/3732 [20:24<4:35:30,  4.76s/it]Giga generation stopped with reason: blacklist
#   9%|███▍                                  | 332/3732 [25:50<4:07:04,  4.36s/it]Giga generation stopped with reason: blacklist
#  11%|████                                  | 397/3732 [30:46<4:17:57,  4.64s/it]Giga generation stopped with reason: blacklist
#  12%|████▌                                 | 446/3732 [34:32<4:38:58,  5.09s/it]Giga generation stopped with reason: blacklist
#  12%|████▋                                 | 461/3732 [35:38<4:17:33,  4.72s/it]Giga generation stopped with reason: blacklist
#  12%|████▋                                 | 465/3732 [35:56<4:23:00,  4.83s/it]Giga generation stopped with reason: blacklist
#  13%|████▉                                 | 487/3732 [37:40<4:23:15,  4.87s/it]Giga generation stopped with reason: blacklist
#  14%|█████▎                                | 523/3732 [40:27<3:54:49,  4.39s/it]Giga generation stopped with reason: blacklist
#  15%|█████▌                                | 544/3732 [42:04<4:25:45,  5.00s/it]Giga generation stopped with reason: blacklist
#  16%|██████                                | 591/3732 [45:40<3:41:46,  4.24s/it]Giga generation stopped with reason: blacklist
#  16%|██████▏                               | 608/3732 [46:56<4:18:17,  4.96s/it]Giga generation stopped with reason: blacklist
#  16%|██████▏                               | 610/3732 [47:07<4:37:32,  5.33s/it]Giga generation stopped with reason: blacklist
#  17%|██████▎                               | 617/3732 [47:39<3:47:22,  4.38s/it]Giga generation stopped with reason: blacklist
#  17%|██████▍                               | 627/3732 [48:24<4:01:11,  4.66s/it]Giga generation stopped with reason: blacklist
#  17%|██████▍                               | 632/3732 [48:45<3:45:38,  4.37s/it]Giga generation stopped with reason: blacklist
#  17%|██████▍                               | 637/3732 [49:07<3:50:33,  4.47s/it]Giga generation stopped with reason: blacklist
#  18%|██████▋                               | 654/3732 [50:28<3:56:26,  4.61s/it]Giga generation stopped with reason: blacklist
#  18%|██████▋                               | 656/3732 [50:36<3:52:02,  4.53s/it]Giga generation stopped with reason: blacklist
#  18%|██████▉                               | 683/3732 [52:46<4:07:34,  4.87s/it]Giga generation stopped with reason: blacklist
#  19%|███████▏                              | 700/3732 [54:09<3:38:48,  4.33s/it]Giga generation stopped with reason: blacklist
#  19%|███████▏                              | 704/3732 [54:30<4:22:52,  5.21s/it]Giga generation stopped with reason: blacklist
#  19%|███████▎                              | 717/3732 [55:31<3:35:47,  4.29s/it]Giga generation stopped with reason: blacklist
#  21%|███████▌                            | 779/3732 [1:00:13<3:35:50,  4.39s/it]Giga generation stopped with reason: blacklist
#  21%|███████▋                            | 792/3732 [1:01:13<3:33:19,  4.35s/it]Giga generation stopped with reason: blacklist
#  22%|███████▋                            | 803/3732 [1:01:59<3:23:31,  4.17s/it]Giga generation stopped with reason: blacklist
#  22%|████████                            | 837/3732 [1:04:37<3:43:54,  4.64s/it]Giga generation stopped with reason: blacklist
#  23%|████████▍                           | 870/3732 [1:07:18<3:40:46,  4.63s/it]Giga generation stopped with reason: blacklist
#  24%|████████▋                           | 896/3732 [1:09:20<3:51:12,  4.89s/it]Giga generation stopped with reason: blacklist
#  26%|█████████▌                          | 985/3732 [1:16:23<3:16:50,  4.30s/it]Giga generation stopped with reason: blacklist
#  27%|█████████▌                          | 995/3732 [1:17:12<3:27:48,  4.56s/it]Giga generation stopped with reason: blacklist
#  27%|█████████▌                          | 996/3732 [1:17:16<3:18:01,  4.34s/it]Giga generation stopped with reason: blacklist
#  27%|█████████▌                         | 1018/3732 [1:18:56<3:17:47,  4.37s/it]Giga generation stopped with reason: blacklist
#  29%|██████████▏                        | 1084/3732 [1:24:01<3:14:47,  4.41s/it]Giga generation stopped with reason: blacklist
#  29%|██████████▎                        | 1093/3732 [1:24:40<3:10:33,  4.33s/it]Giga generation stopped with reason: blacklist
#  30%|██████████▍                        | 1116/3732 [1:26:30<3:23:47,  4.67s/it]Giga generation stopped with reason: blacklist
#  30%|██████████▌                        | 1124/3732 [1:27:14<4:12:16,  5.80s/it]Giga generation stopped with reason: blacklist
#  31%|██████████▊                        | 1151/3732 [1:29:26<3:19:46,  4.64s/it]Giga generation stopped with reason: blacklist
#  31%|██████████▉                        | 1168/3732 [1:30:42<3:12:16,  4.50s/it]Giga generation stopped with reason: blacklist
#  32%|███████████▏                       | 1197/3732 [1:32:53<3:00:02,  4.26s/it]Giga generation stopped with reason: blacklist
#  33%|███████████▌                       | 1231/3732 [1:35:30<2:59:09,  4.30s/it]Giga generation stopped with reason: blacklist
#  34%|███████████▋                       | 1252/3732 [1:37:06<3:07:31,  4.54s/it]Giga generation stopped with reason: blacklist
#  34%|███████████▊                       | 1257/3732 [1:37:27<2:59:40,  4.36s/it]Giga generation stopped with reason: blacklist
#  34%|████████████                       | 1284/3732 [1:39:30<3:02:46,  4.48s/it]Giga generation stopped with reason: blacklist
#  35%|████████████                       | 1288/3732 [1:39:47<2:57:07,  4.35s/it]Giga generation stopped with reason: blacklist
#  35%|████████████                       | 1290/3732 [1:39:55<2:48:07,  4.13s/it]Giga generation stopped with reason: blacklist
#  35%|████████████▏                      | 1300/3732 [1:40:40<2:57:32,  4.38s/it]Giga generation stopped with reason: blacklist
#  35%|████████████▎                      | 1309/3732 [1:41:21<3:12:55,  4.78s/it]Giga generation stopped with reason: blacklist
#  35%|████████████▎                      | 1310/3732 [1:41:26<3:09:25,  4.69s/it]Giga generation stopped with reason: blacklist
#  35%|████████████▎                      | 1318/3732 [1:42:03<3:08:16,  4.68s/it]Giga generation stopped with reason: blacklist
#  35%|████████████▍                      | 1323/3732 [1:42:27<3:07:34,  4.67s/it]Giga generation stopped with reason: blacklist
#  37%|████████████▊                      | 1370/3732 [1:46:05<2:52:41,  4.39s/it]Giga generation stopped with reason: blacklist
#  37%|████████████▉                      | 1385/3732 [1:47:13<2:52:31,  4.41s/it]Giga generation stopped with reason: blacklist
#  37%|█████████████                      | 1394/3732 [1:47:53<3:03:26,  4.71s/it]Giga generation stopped with reason: blacklist
#  38%|█████████████▎                     | 1419/3732 [1:49:57<3:20:03,  5.19s/it]Giga generation stopped with reason: blacklist
#  39%|█████████████▌                     | 1448/3732 [1:52:08<2:48:12,  4.42s/it]Giga generation stopped with reason: blacklist
#  39%|█████████████▋                     | 1458/3732 [1:52:59<3:26:20,  5.44s/it]Giga generation stopped with reason: blacklist
#  39%|█████████████▋                     | 1459/3732 [1:53:03<3:07:16,  4.94s/it]Giga generation stopped with reason: blacklist
#  39%|█████████████▊                     | 1474/3732 [1:54:08<2:53:50,  4.62s/it]Giga generation stopped with reason: blacklist
#  40%|█████████████▉                     | 1488/3732 [1:55:18<3:31:55,  5.67s/it]Giga generation stopped with reason: blacklist
#  40%|██████████████                     | 1497/3732 [1:56:05<2:55:58,  4.72s/it]Giga generation stopped with reason: blacklist
#  41%|██████████████▎                    | 1526/3732 [1:58:25<2:51:04,  4.65s/it]Giga generation stopped with reason: blacklist
#  42%|██████████████▋                    | 1560/3732 [2:00:55<2:33:00,  4.23s/it]Giga generation stopped with reason: blacklist
#  42%|██████████████▋                    | 1568/3732 [2:01:31<2:43:56,  4.55s/it]Giga generation stopped with reason: blacklist
#  42%|██████████████▊                    | 1574/3732 [2:02:00<3:06:03,  5.17s/it]Giga generation stopped with reason: blacklist
#  43%|███████████████▏                   | 1622/3732 [2:05:40<2:37:03,  4.47s/it]Giga generation stopped with reason: blacklist
#  44%|███████████████▍                   | 1652/3732 [2:07:55<2:36:23,  4.51s/it]Giga generation stopped with reason: blacklist
#  45%|███████████████▌                   | 1664/3732 [2:08:48<2:35:39,  4.52s/it]Giga generation stopped with reason: blacklist
#  45%|███████████████▌                   | 1666/3732 [2:08:57<2:30:39,  4.38s/it]Giga generation stopped with reason: blacklist
#  45%|███████████████▋                   | 1671/3732 [2:09:20<2:36:03,  4.54s/it]Giga generation stopped with reason: blacklist
#  46%|████████████████                   | 1717/3732 [2:13:03<2:38:31,  4.72s/it]Giga generation stopped with reason: blacklist
#  46%|████████████████                   | 1718/3732 [2:13:07<2:30:06,  4.47s/it]Giga generation stopped with reason: blacklist
#  46%|████████████████▏                  | 1724/3732 [2:13:34<2:38:58,  4.75s/it]Giga generation stopped with reason: blacklist
#  47%|████████████████▌                  | 1770/3732 [2:17:02<2:18:27,  4.23s/it]Giga generation stopped with reason: blacklist
#  48%|████████████████▋                  | 1783/3732 [2:18:00<2:21:56,  4.37s/it]Giga generation stopped with reason: blacklist
#  48%|████████████████▊                  | 1796/3732 [2:19:01<2:24:38,  4.48s/it]Giga generation stopped with reason: blacklist
#  49%|█████████████████                  | 1825/3732 [2:21:16<2:50:34,  5.37s/it]Giga generation stopped with reason: blacklist
#  49%|█████████████████▏                 | 1829/3732 [2:21:34<2:30:56,  4.76s/it]Giga generation stopped with reason: blacklist
#  50%|█████████████████▍                 | 1865/3732 [2:24:21<2:11:24,  4.22s/it]Giga generation stopped with reason: blacklist
#  50%|█████████████████▌                 | 1866/3732 [2:24:24<2:07:44,  4.11s/it]Giga generation stopped with reason: blacklist
#  51%|█████████████████▊                 | 1896/3732 [2:26:49<2:22:28,  4.66s/it]Giga generation stopped with reason: blacklist
#  51%|█████████████████▉                 | 1906/3732 [2:27:36<2:27:19,  4.84s/it]Giga generation stopped with reason: blacklist
#  52%|██████████████████▏                | 1945/3732 [2:30:33<2:06:45,  4.26s/it]Giga generation stopped with reason: blacklist
#  52%|██████████████████▎                | 1949/3732 [2:30:53<2:28:29,  5.00s/it]Giga generation stopped with reason: blacklist
#  53%|██████████████████▌                | 1982/3732 [2:33:21<2:07:06,  4.36s/it]Giga generation stopped with reason: blacklist
#  55%|███████████████████▏               | 2050/3732 [2:38:36<2:02:46,  4.38s/it]Giga generation stopped with reason: blacklist
#  55%|███████████████████▎               | 2053/3732 [2:38:50<2:11:13,  4.69s/it]Giga generation stopped with reason: blacklist
#  56%|███████████████████▌               | 2085/3732 [2:41:21<2:13:35,  4.87s/it]Giga generation stopped with reason: blacklist
#  57%|███████████████████▊               | 2116/3732 [2:43:45<1:56:39,  4.33s/it]Giga generation stopped with reason: blacklist
#  59%|████████████████████▋              | 2205/3732 [2:50:30<1:48:39,  4.27s/it]Giga generation stopped with reason: blacklist
#  60%|████████████████████▉              | 2231/3732 [2:52:36<2:02:06,  4.88s/it]Giga generation stopped with reason: blacklist
#  60%|█████████████████████▏             | 2255/3732 [2:54:24<1:45:16,  4.28s/it]Giga generation stopped with reason: blacklist
#  61%|█████████████████████▏             | 2265/3732 [2:55:14<2:05:27,  5.13s/it]Giga generation stopped with reason: blacklist
#  61%|█████████████████████▎             | 2269/3732 [2:55:32<1:49:30,  4.49s/it]Giga generation stopped with reason: blacklist
#  62%|█████████████████████▌             | 2303/3732 [2:58:01<1:45:00,  4.41s/it]Giga generation stopped with reason: blacklist
#  62%|█████████████████████▋             | 2318/3732 [2:59:12<1:48:58,  4.62s/it]Giga generation stopped with reason: blacklist
#  62%|█████████████████████▊             | 2332/3732 [3:00:19<1:50:27,  4.73s/it]Giga generation stopped with reason: blacklist
#  63%|██████████████████████             | 2346/3732 [3:01:29<1:56:17,  5.03s/it]Giga generation stopped with reason: blacklist
#  63%|██████████████████████             | 2350/3732 [3:01:48<1:48:31,  4.71s/it]Giga generation stopped with reason: blacklist
#  64%|██████████████████████▎            | 2376/3732 [3:03:54<1:36:55,  4.29s/it]Giga generation stopped with reason: blacklist
#  64%|██████████████████████▌            | 2406/3732 [3:06:11<1:41:24,  4.59s/it]Giga generation stopped with reason: blacklist
#  65%|██████████████████████▊            | 2426/3732 [3:07:39<1:39:40,  4.58s/it]Giga generation stopped with reason: blacklist
#  65%|██████████████████████▊            | 2431/3732 [3:08:01<1:37:22,  4.49s/it]Giga generation stopped with reason: blacklist
#  65%|██████████████████████▊            | 2437/3732 [3:08:27<1:30:53,  4.21s/it]Giga generation stopped with reason: blacklist
#  67%|███████████████████████▎           | 2491/3732 [3:12:33<1:34:09,  4.55s/it]Giga generation stopped with reason: blacklist
#  68%|███████████████████████▋           | 2529/3732 [3:15:39<1:41:11,  5.05s/it]Giga generation stopped with reason: blacklist
#  69%|████████████████████████           | 2562/3732 [3:18:12<1:32:50,  4.76s/it]Giga generation stopped with reason: blacklist
#  69%|████████████████████████▏          | 2573/3732 [3:19:08<1:45:14,  5.45s/it]Giga generation stopped with reason: blacklist
#  70%|████████████████████████▌          | 2620/3732 [3:22:46<1:33:34,  5.05s/it]Giga generation stopped with reason: blacklist
#  71%|████████████████████████▋          | 2636/3732 [3:24:02<1:25:35,  4.69s/it]Giga generation stopped with reason: blacklist
#  71%|████████████████████████▉          | 2663/3732 [3:26:04<1:18:55,  4.43s/it]Giga generation stopped with reason: blacklist
#  72%|█████████████████████████▏         | 2685/3732 [3:27:50<1:25:50,  4.92s/it]Giga generation stopped with reason: blacklist
#  73%|█████████████████████████▍         | 2709/3732 [3:29:38<1:22:16,  4.83s/it]Giga generation stopped with reason: blacklist
#  73%|█████████████████████████▌         | 2727/3732 [3:31:01<1:28:03,  5.26s/it]Giga generation stopped with reason: blacklist
#  74%|█████████████████████████▉         | 2762/3732 [3:33:50<1:14:34,  4.61s/it]Giga generation stopped with reason: blacklist
#  74%|██████████████████████████         | 2776/3732 [3:34:57<1:15:41,  4.75s/it]Giga generation stopped with reason: blacklist
#  75%|██████████████████████████▎        | 2803/3732 [3:36:57<1:08:01,  4.39s/it]Giga generation stopped with reason: blacklist
#  76%|██████████████████████████▋        | 2842/3732 [3:40:14<1:06:47,  4.50s/it]Giga generation stopped with reason: blacklist
#  78%|███████████████████████████▏       | 2900/3732 [3:44:45<1:03:26,  4.58s/it]Giga generation stopped with reason: blacklist
#  78%|███████████████████████████▎       | 2906/3732 [3:45:11<1:03:00,  4.58s/it]Giga generation stopped with reason: blacklist
#  78%|████████████████████████████▉        | 2922/3732 [3:46:22<59:42,  4.42s/it]Giga generation stopped with reason: blacklist
#  79%|███████████████████████████▋       | 2950/3732 [3:48:32<1:00:17,  4.63s/it]Giga generation stopped with reason: blacklist
#  79%|█████████████████████████████▎       | 2957/3732 [3:49:04<58:44,  4.55s/it]Giga generation stopped with reason: blacklist
#  80%|█████████████████████████████▍       | 2971/3732 [3:50:09<57:07,  4.50s/it]Giga generation stopped with reason: blacklist
#  82%|██████████████████████████████▎      | 3058/3732 [3:56:39<48:35,  4.33s/it]Giga generation stopped with reason: blacklist
#  83%|██████████████████████████████▊      | 3103/3732 [4:00:11<49:49,  4.75s/it]Giga generation stopped with reason: blacklist
#  84%|██████████████████████████████▉      | 3126/3732 [4:02:05<51:07,  5.06s/it]Giga generation stopped with reason: blacklist
#  84%|███████████████████████████████      | 3137/3732 [4:02:56<45:16,  4.57s/it]Giga generation stopped with reason: blacklist
#  84%|███████████████████████████████▏     | 3148/3732 [4:03:44<40:52,  4.20s/it]Giga generation stopped with reason: blacklist
#  85%|███████████████████████████████▎     | 3164/3732 [4:04:54<44:38,  4.71s/it]Giga generation stopped with reason: blacklist
#  86%|███████████████████████████████▋     | 3191/3732 [4:06:54<41:09,  4.57s/it]Giga generation stopped with reason: blacklist
#  86%|███████████████████████████████▉     | 3217/3732 [4:08:59<44:45,  5.21s/it]Giga generation stopped with reason: blacklist
#  87%|████████████████████████████████     | 3235/3732 [4:10:33<40:21,  4.87s/it]Giga generation stopped with reason: blacklist
#  87%|████████████████████████████████▎    | 3258/3732 [4:12:20<34:45,  4.40s/it]Giga generation stopped with reason: blacklist
#  87%|████████████████████████████████▎    | 3261/3732 [4:12:33<34:27,  4.39s/it]Giga generation stopped with reason: blacklist
#  88%|████████████████████████████████▍    | 3277/3732 [4:13:53<44:46,  5.90s/it]Giga generation stopped with reason: blacklist
#  89%|████████████████████████████████▉    | 3316/3732 [4:17:03<34:30,  4.98s/it]Giga generation stopped with reason: blacklist
#  90%|█████████████████████████████████▏   | 3345/3732 [4:19:18<28:20,  4.39s/it]Giga generation stopped with reason: blacklist
#  91%|█████████████████████████████████▌   | 3383/3732 [4:22:16<26:40,  4.59s/it]Giga generation stopped with reason: blacklist
#  91%|█████████████████████████████████▋   | 3395/3732 [4:23:14<28:18,  5.04s/it]Giga generation stopped with reason: blacklist
#  91%|█████████████████████████████████▊   | 3408/3732 [4:24:13<24:11,  4.48s/it]Giga generation stopped with reason: blacklist
#  91%|█████████████████████████████████▊   | 3411/3732 [4:24:26<22:22,  4.18s/it]Giga generation stopped with reason: blacklist
#  92%|█████████████████████████████████▉   | 3421/3732 [4:25:16<28:28,  5.49s/it]Giga generation stopped with reason: blacklist
#  92%|█████████████████████████████████▉   | 3429/3732 [4:25:56<24:30,  4.85s/it]Giga generation stopped with reason: blacklist
#  92%|██████████████████████████████████▏  | 3447/3732 [4:27:21<20:53,  4.40s/it]Giga generation stopped with reason: blacklist
#  95%|██████████████████████████████████▉  | 3527/3732 [4:33:28<14:57,  4.38s/it]Giga generation stopped with reason: blacklist
#  95%|███████████████████████████████████▏ | 3551/3732 [4:35:23<15:57,  5.29s/it]Giga generation stopped with reason: blacklist
#  95%|███████████████████████████████████▏ | 3553/3732 [4:35:34<16:11,  5.43s/it]Giga generation stopped with reason: blacklist
#  96%|███████████████████████████████████▎ | 3567/3732 [4:36:46<14:43,  5.35s/it]Giga generation stopped with reason: blacklist
#  96%|███████████████████████████████████▋ | 3598/3732 [4:39:17<10:49,  4.84s/it]Giga generation stopped with reason: blacklist
#  97%|████████████████████████████████████ | 3635/3732 [4:42:10<07:09,  4.43s/it]Giga generation stopped with reason: blacklist
#  98%|████████████████████████████████████▎| 3662/3732 [4:44:21<05:39,  4.85s/it]Giga generation stopped with reason: blacklist
#  98%|████████████████████████████████████▍| 3669/3732 [4:44:57<05:28,  5.21s/it]Giga generation stopped with reason: blacklist
# 100%|████████████████████████████████████▊| 3717/3732 [4:48:48<01:10,  4.68s/it]Giga generation stopped with reason: blacklist
# 100%|████████████████████████████████████▉| 3724/3732 [4:49:20<00:37,  4.71s/it]Giga generation stopped with reason: blacklist
# 100%|█████████████████████████████████████| 3732/3732 [4:49:53<00:00,  4.66s/it]

# %%
len(true_labels), len(preds)
# Out:
# (93111, 93111)

# %%
def calc_metrics_no_proba(y_true, y_pred):
    print('Доля пробелов:', (y_true == 7).mean())
#     print('Accuracy:', top_k_accuracy_score(y_true, y_pred_proba, k=1))
#     print('Top-2 Accuracy:', top_k_accuracy_score(y_true, y_pred_proba, k=2))
#     rint('ROC-AUC (OVR):',roc_auc_score(y_true, y_pred_proba, multi_class='ovr'))
#     print('AUC-PR:',average_precision_score(y_true, y_pred_proba, average='weighted'))
    
    metrics = []
    metrics.append(list(dict(sorted(Counter(y_true).items())).values()))
    metrics.append(f1_score(y_true, y_pred, average=None))
    metrics.append(precision_score(y_true, y_pred, average=None, zero_division=0))
    metrics.append(recall_score(y_true, y_pred, average=None, zero_division=0))
#     metrics.append(roc_auc_score(y_true, y_pred_proba, multi_class='ovr', average=None))
#     metrics.append(average_precision_score(y_true, y_pred_proba, average=None))
    metrics_index = ['Count', 'F1-Score', 'Precision', 'Recall']
#                      'ROC-AUC', 'AUC-PR']
    df_metrics = pd.DataFrame(metrics, columns=le.classes_, index=metrics_index)
    
    return df_metrics

# %%
le = joblib.load('le.joblib')

y_pred = le.transform(preds)
y_true = le.transform(true_labels)

calc_metrics_no_proba(y_true, y_pred)
# Out:
# Доля пробелов: 0.8539592529346693
#                    !            ,            .  ...           :      ;  \
# Count      29.000000  6836.000000  6314.000000  9.0  202.000000  179.0
# F1-Score    0.060606     0.760332     0.804143  0.0    0.361963    0.0
# Precision   0.250000     0.726075     0.892733  0.0    0.475806    0.0
# Recall      0.034483     0.797981     0.731549  0.0    0.292079    0.0
#
#                    ?             o
# Count      29.000000  79513.000000
# F1-Score    0.490566      0.980632
# Precision   0.541667      0.976232
# Recall      0.448276      0.985072
